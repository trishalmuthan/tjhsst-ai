# %%
import nltk

# %%
from nltk.corpus import state_union

# %%
cfd = nltk.ConditionalFreqDist(
    (condition, fileid[:4])
    for fileid in state_union.fileids()
    for word in state_union.words(fileid)
    for condition in ['men', 'women', 'people']
    if word.lower().startswith(condition)
)

# %%
years = range(1945, 2007, 5)
cfd.tabulate(samples = [str(y) for y in years], conditions = ['men', 'women', 'people'])
cfd.plot()
# Out:
#        1945 1950 1955 1960 1965 1970 1975 1980 1985 1990 1995 2000 2005
#    men    2    6    9    2   22    3    0    1    1    3    3   11    8
#  women    2    2    0    0    3    0    0    2    1    2    3    7   11
# people   10   23   31   18   30   24   14   13   12   10   73   41   18
